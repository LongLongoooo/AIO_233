# %% [markdown]
# <a href="https://colab.research.google.com/github/LongLongoooo/AIO_233/blob/AIO_Module_5/M05W03_%5BMLP__Car_Efficiency_Prediction%5D.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !gdown --id 1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# Out:
# /usr/local/lib/python3.10/dist-packages/gdown/__main__.py:140: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1qiUDDoYyRLBiKOoYWdFl_5WByHE8Cugu
# To: /content/Auto_MPG_data.csv
# 100% 15.4k/15.4k [00:00<00:00, 44.5MB/s]

# %% [markdown]
# # ***Car Efficiency Prediction***

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
# Seeding all random values to get the consistent values
random_state = 59
np.random.seed(random_state)
torch.manual_seed(random_state)
if torch.cuda.is_available():
  torch.cuda.manual_seed(random_state)
# Device's settings for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Read dataset
carset = pd.read_csv("/content/Auto_MPG_data.csv")
carset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 392 entries, 0 to 391
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   MPG           392 non-null    float64
#  1   Cylinders     392 non-null    int64
#  2   Displacement  392 non-null    float64
#  3   Horsepower    392 non-null    float64
#  4   Weight        392 non-null    float64
#  5   Acceleration  392 non-null    float64
#  6   Model Year    392 non-null    int64
#  7   Europe        392 non-null    int64
#  8   Japan         392 non-null    int64
#  9   USA           392 non-null    int64
# dtypes: float64(5), int64(5)
# memory usage: 30.8 KB

# %%
# Preprocessing

# Split X, y
X = carset.drop(columns="MPG")
y = carset["MPG"].values

# Train test and val split
test_size = 0.125
val_size = 0.2
is_shuffle = True

X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=val_size, random_state=random_state, shuffle=is_shuffle)
X_train, X_test, y_train, y_test = train_test_split(X_train, y_train, test_size=test_size, random_state=random_state,shuffle=is_shuffle)

# Input Normalization
normalizer = StandardScaler()
X_train = normalizer.fit_transform(X_train)
X_val= normalizer.transform(X_val)
X_test = normalizer.transform(X_test)

# Convert to tensor
X_train = torch.tensor(X_train, dtype=torch.float32)
X_val = torch.tensor(X_val, dtype=torch.float32)
X_test = torch.tensor(X_test, dtype=torch.float32)
y_train = torch.tensor(y_train, dtype=torch.float32)
y_val = torch.tensor(y_val, dtype=torch.float32)
y_test = torch.tensor(y_test, dtype=torch.float32)

# %%
# Construct DataLoader
class CustomDataset(Dataset):
  def __init__(self, X, y):
    self.X = X
    self.y = y

  def __len__(self):
    return len(self.y)

  def __getitem__(self, idx):
    return self.X[idx], self.y[idx]

batch_size = 32
train_dataset = CustomDataset(X_train, y_train)
val_dataset = CustomDataset(X_val, y_val)
train_loader = DataLoader(train_dataset,
                          batch_size=batch_size,
                          shuffle=True)

val_loader = DataLoader(val_dataset,
                        batch_size=batch_size,
                        shuffle=True)

# %%
# Construct MLP network
class MLP(nn.Module):
  def __init__(self, input_dims, hidden_dims, output_dims):
    super().__init__()
    self.linear1 = nn.Linear(input_dims, hidden_dims)
    self.linear2 = nn.Linear(hidden_dims, hidden_dims)
    self.output = nn.Linear(hidden_dims, output_dims)

  def forward(self, x):
    x = self.linear1(x) #Input to first hidden layer
    x = F.gelu(x) #First hidden layer to activation function
    x = self.linear2(x) #First activation to second hidden layer
    x = F.gelu(x) #to second activation function
    out = self.output(x) #to output
    return out.squeeze(1) #remove dimensions which equals to 1

input_dims = X.shape[1]
hidden_dims = 64
output_dims = 1

model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

# %%
# Loss and Optimizer
lr = 0.01
criterion = nn.MSELoss()
optimizer = torch.optim.Adam(model.parameters(), lr=lr)

# %%
# Construct R^2 score function
def r_squared(y_hat, y):
  y_hat = torch.Tensor(y_hat).to(device)
  y = torch.Tensor(y).to(device)
  mean_true = torch.mean(y)
  ss_res = torch.sum((y - y_hat)**2)
  ss_rot = torch.sum((y - mean_true)**2)
  r2 = 1 - (ss_res / ss_rot)
  return r2

# %%
# Training
epochs = 100
train_losses = []
train_r2 = []
val_losses = []
val_r2 = []
for epoch in range(epochs):
  # Training part
  train_loss = 0.0
  train_target = []
  train_predict = []
  model.train()

  for X_samples, y_samples in train_loader:
    X_samples = X_samples.to(device)
    y_samples = y_samples.to(device)
    optimizer.zero_grad()
    outputs = model(X_samples)
    train_predict += outputs.tolist() #Like append to list
    train_target += y_samples.tolist()
    loss = criterion(outputs, y_samples)
    loss.backward()
    optimizer.step()
    train_loss += loss.item()

  train_loss /= len(train_loader)
  train_losses.append(train_loss)
  train_r2.append(r_squared(train_predict, train_target))
  model.eval()

  # Evaluating part
  val_loss = 0.0
  val_target = []
  val_predict = []
  with torch.no_grad():
    for X_samples, y_samples in val_loader:
      X_samples = X_samples.to(device)
      y_samples = y_samples.to(device)
      outputs = model(X_samples)
      val_predict += outputs.tolist()
      val_target += y_samples.tolist()
      loss = criterion(outputs, y_samples)
      val_loss += loss.item()
  val_loss /= len(val_loader)
  val_losses.append(val_loss)
  val_r2.append(r_squared(val_predict, val_target))
  print (f'\ nEPOCH { epoch + 1}:\ tTraining loss : { train_loss :.3f}\tValidation loss : { val_loss :.3f}')
# Out:
# \ nEPOCH 1:\ tTraining loss : 549.238	Validation loss : 376.897
# \ nEPOCH 2:\ tTraining loss : 189.761	Validation loss : 88.291
# \ nEPOCH 3:\ tTraining loss : 53.926	Validation loss : 28.500
# \ nEPOCH 4:\ tTraining loss : 26.776	Validation loss : 17.013
# \ nEPOCH 5:\ tTraining loss : 15.571	Validation loss : 12.654
# \ nEPOCH 6:\ tTraining loss : 12.560	Validation loss : 8.459
# \ nEPOCH 7:\ tTraining loss : 10.209	Validation loss : 6.579
# \ nEPOCH 8:\ tTraining loss : 7.881	Validation loss : 5.853
# \ nEPOCH 9:\ tTraining loss : 7.877	Validation loss : 7.786
# \ nEPOCH 10:\ tTraining loss : 7.583	Validation loss : 5.865
# \ nEPOCH 11:\ tTraining loss : 7.420	Validation loss : 6.083
# \ nEPOCH 12:\ tTraining loss : 7.862	Validation loss : 5.586
# \ nEPOCH 13:\ tTraining loss : 7.942	Validation loss : 5.753
# \ nEPOCH 14:\ tTraining loss : 7.128	Validation loss : 6.659
# \ nEPOCH 15:\ tTraining loss : 7.049	Validation loss : 6.524
# \ nEPOCH 16:\ tTraining loss : 6.867	Validation loss : 5.405
# \ nEPOCH 17:\ tTraining loss : 6.737	Validation loss : 5.857
# \ nEPOCH 18:\ tTraining loss : 6.854	Validation loss : 6.174
# \ nEPOCH 19:\ tTraining loss : 7.252	Validation loss : 7.488
# \ nEPOCH 20:\ tTraining loss : 7.450	Validation loss : 4.976
# \ nEPOCH 21:\ tTraining loss : 6.518	Validation loss : 5.682
# \ nEPOCH 22:\ tTraining loss : 6.539	Validation loss : 6.308
# \ nEPOCH 23:\ tTraining loss : 7.547	Validation loss : 6.633
# \ nEPOCH 24:\ tTraining loss : 7.470	Validation loss : 7.205
# \ nEPOCH 25:\ tTraining loss : 6.889	Validation loss : 6.514
# \ nEPOCH 26:\ tTraining loss : 7.067	Validation loss : 5.750
# \ nEPOCH 27:\ tTraining loss : 6.938	Validation loss : 5.803
# \ nEPOCH 28:\ tTraining loss : 6.777	Validation loss : 6.263
# \ nEPOCH 29:\ tTraining loss : 7.129	Validation loss : 6.184
# \ nEPOCH 30:\ tTraining loss : 6.474	Validation loss : 5.380
# \ nEPOCH 31:\ tTraining loss : 6.807	Validation loss : 6.164
# \ nEPOCH 32:\ tTraining loss : 6.327	Validation loss : 6.930
# \ nEPOCH 33:\ tTraining loss : 6.652	Validation loss : 5.204
# \ nEPOCH 34:\ tTraining loss : 5.881	Validation loss : 6.728
# \ nEPOCH 35:\ tTraining loss : 6.313	Validation loss : 5.347
# \ nEPOCH 36:\ tTraining loss : 6.327	Validation loss : 6.215
# \ nEPOCH 37:\ tTraining loss : 8.561	Validation loss : 6.527
# \ nEPOCH 38:\ tTraining loss : 6.769	Validation loss : 6.898
# \ nEPOCH 81:\ tTraining loss : 5.159	Validation loss : 5.623
# \ nEPOCH 82:\ tTraining loss : 6.603	Validation loss : 10.133
# \ nEPOCH 83:\ tTraining loss : 6.579	Validation loss : 7.107
# \ nEPOCH 84:\ tTraining loss : 6.582	Validation loss : 7.559
# \ nEPOCH 85:\ tTraining loss : 6.695	Validation loss : 9.876
# \ nEPOCH 86:\ tTraining loss : 7.212	Validation loss : 6.853
# \ nEPOCH 87:\ tTraining loss : 5.630	Validation loss : 7.632
# \ nEPOCH 88:\ tTraining loss : 5.207	Validation loss : 5.625
# \ nEPOCH 89:\ tTraining loss : 4.923	Validation loss : 6.452
# \ nEPOCH 90:\ tTraining loss : 5.257	Validation loss : 7.114
# \ nEPOCH 91:\ tTraining loss : 4.973	Validation loss : 5.864
# \ nEPOCH 92:\ tTraining loss : 5.232	Validation loss : 7.100
# \ nEPOCH 93:\ tTraining loss : 4.898	Validation loss : 6.325
# \ nEPOCH 94:\ tTraining loss : 4.793	Validation loss : 7.261
# \ nEPOCH 95:\ tTraining loss : 5.081	Validation loss : 5.913
# \ nEPOCH 96:\ tTraining loss : 4.502	Validation loss : 7.018
# \ nEPOCH 97:\ tTraining loss : 4.717	Validation loss : 6.104
# \ nEPOCH 98:\ tTraining loss : 4.478	Validation loss : 5.184
# \ nEPOCH 99:\ tTraining loss : 5.298	Validation loss : 7.962
# \ nEPOCH 100:\ tTraining loss : 5.711	Validation loss : 5.861

# %%
# Model Evaluation
model.eval()
with torch.no_grad():
  y_pred = model(X_test)
  test_set_r2 = r_squared(y_pred, y_test)
  print ('Evaluation on test set :')
  print (f'R2: { test_set_r2 }')
# Out:
# Evaluation on test set :
# R2: 0.8570410013198853

# %%
fig, ax = plt.subplots(2, 2, figsize=(12, 10))

ax[0, 0].plot(train_losses)
ax[0, 0].set(xlabel='Epoch', ylabel='Loss')
ax[0, 0].set_title('Training Loss')

ax[0, 1].plot(val_losses, 'orange')
ax[0, 1].set(xlabel='Epoch', ylabel='Loss')
ax[0, 1].set_title('Validation Loss')

ax[1, 0].plot(train_r2)
ax[1, 0].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 0].set_title('Training Accuracy')

ax[1, 1].plot(val_r2, 'orange')
ax[1, 1].set(xlabel='Epoch', ylabel='Accuracy')
ax[1, 1].set_title('Validation Accuracy')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import torch

# Set the model to evaluation mode
model.eval()
with torch.no_grad():
    # Get predictions from the model
    y_pred = model(X_test)

    # Convert predictions and true values to CPU and detach from computation graph if using GPU
    y_pred_np = y_pred.cpu().numpy()
    y_test_np = y_test.cpu().numpy()

    # Plot line chart
    plt.figure(figsize=(12, 6))
    plt.plot(y_test_np, label='True Test Values', color='blue', linewidth=2)
    plt.plot(y_pred_np, label='Predicted Test Values', color='orange', linestyle='--', linewidth=2)
    plt.xlabel('Sample Index')
    plt.ylabel('Value')
    plt.title('True vs Predicted Test Values')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # **Linear Regression (Testing)**

# %%
class LinearRegression(nn.Module):
    def __init__(self, input_dims):
        super(LinearRegression, self).__init__()
        self.linear = nn.Linear(input_dims, 1)

    # Corrected indentation for forward function
    def forward(self, x):
        x = self.linear(x)
        return x.squeeze(1)

LRegression_model = LinearRegression(X.shape[1])
lr = 0.01
# Loss and Optimal
L_criterion = nn.MSELoss()
L_optimizer = torch.optim.SGD(LRegression_model.parameters(), lr=lr)

# Training
epochs = 100
train_losses = []
train_r2 = []
val_losses = []
val_r2 = []
for epoch in range(epochs):
  # Training part
  train_loss = 0.0
  train_target = []
  train_predict = []
  LRegression_model.train()

  for X_samples, y_samples in train_loader:
    X_samples = X_samples.to(device)
    y_samples = y_samples.to(device)
    L_optimizer.zero_grad()
    outputs = LRegression_model(X_samples)
    train_predict += outputs.tolist() #Like append to list
    train_target += y_samples.tolist()
    loss = L_criterion(outputs, y_samples)
    loss.backward()
    L_optimizer.step()
    train_loss += loss.item()

  train_loss /= len(train_loader)
  train_losses.append(train_loss)
  train_r2.append(r_squared(train_predict, train_target))
  LRegression_model.eval()

  # Evaluating part
  val_loss = 0.0
  val_target = []
  val_predict = []
  with torch.no_grad():
    for X_samples, y_samples in val_loader:
      X_samples = X_samples.to(device)
      y_samples = y_samples.to(device)
      outputs = LRegression_model(X_samples)
      val_predict += outputs.tolist()
      val_target += y_samples.tolist()
      loss = L_criterion(outputs, y_samples)
      val_loss += loss.item()
  val_loss /= len(val_loader)
  val_losses.append(val_loss)
  val_r2.append(r_squared(val_predict, val_target))
  print (f'\ nEPOCH { epoch + 1}:\ tTraining loss : { train_loss :.3f}\tValidation loss : { val_loss :.3f}')
# Model Evaluation
LRegression_model.eval()
with torch.no_grad():
  y_pred = LRegression_model (X_test)
  test_set_r2 = r_squared(y_pred, y_test)
  print ('Evaluation on test set :')
  print (f'R2: { test_set_r2 }')
# Out:
# \ nEPOCH 1:\ tTraining loss : 505.101	Validation loss : 427.674
# \ nEPOCH 2:\ tTraining loss : 343.735	Validation loss : 301.457
# \ nEPOCH 3:\ tTraining loss : 241.830	Validation loss : 215.136
# \ nEPOCH 4:\ tTraining loss : 171.956	Validation loss : 162.662
# \ nEPOCH 5:\ tTraining loss : 122.312	Validation loss : 116.735
# \ nEPOCH 6:\ tTraining loss : 90.589	Validation loss : 84.482
# \ nEPOCH 7:\ tTraining loss : 64.719	Validation loss : 61.823
# \ nEPOCH 8:\ tTraining loss : 49.734	Validation loss : 48.008
# \ nEPOCH 9:\ tTraining loss : 38.477	Validation loss : 35.392
# \ nEPOCH 10:\ tTraining loss : 30.922	Validation loss : 29.768
# \ nEPOCH 11:\ tTraining loss : 25.918	Validation loss : 25.479
# \ nEPOCH 12:\ tTraining loss : 21.490	Validation loss : 20.682
# \ nEPOCH 13:\ tTraining loss : 18.690	Validation loss : 18.366
# \ nEPOCH 14:\ tTraining loss : 16.885	Validation loss : 13.733
# \ nEPOCH 15:\ tTraining loss : 15.972	Validation loss : 13.906
# \ nEPOCH 16:\ tTraining loss : 14.139	Validation loss : 11.626
# \ nEPOCH 17:\ tTraining loss : 13.707	Validation loss : 11.826
# \ nEPOCH 18:\ tTraining loss : 14.265	Validation loss : 10.109
# \ nEPOCH 19:\ tTraining loss : 14.170	Validation loss : 10.089
# \ nEPOCH 20:\ tTraining loss : 12.666	Validation loss : 10.659
# \ nEPOCH 21:\ tTraining loss : 12.965	Validation loss : 9.572
# \ nEPOCH 22:\ tTraining loss : 12.480	Validation loss : 9.907
# \ nEPOCH 23:\ tTraining loss : 12.518	Validation loss : 8.221
# \ nEPOCH 24:\ tTraining loss : 13.075	Validation loss : 8.769
# \ nEPOCH 25:\ tTraining loss : 12.581	Validation loss : 8.797
# \ nEPOCH 26:\ tTraining loss : 12.386	Validation loss : 9.232
# \ nEPOCH 27:\ tTraining loss : 12.718	Validation loss : 8.868
# \ nEPOCH 28:\ tTraining loss : 12.504	Validation loss : 8.219
# \ nEPOCH 71:\ tTraining loss : 11.857	Validation loss : 7.239
# \ nEPOCH 72:\ tTraining loss : 12.176	Validation loss : 8.414
# \ nEPOCH 73:\ tTraining loss : 12.576	Validation loss : 8.271
# \ nEPOCH 74:\ tTraining loss : 11.696	Validation loss : 8.279
# \ nEPOCH 75:\ tTraining loss : 12.159	Validation loss : 8.563
# \ nEPOCH 76:\ tTraining loss : 12.127	Validation loss : 8.504
# \ nEPOCH 77:\ tTraining loss : 11.848	Validation loss : 8.457
# \ nEPOCH 78:\ tTraining loss : 11.854	Validation loss : 9.144
# \ nEPOCH 79:\ tTraining loss : 11.786	Validation loss : 8.096
# \ nEPOCH 80:\ tTraining loss : 11.665	Validation loss : 8.880
# \ nEPOCH 81:\ tTraining loss : 11.530	Validation loss : 7.844
# \ nEPOCH 82:\ tTraining loss : 11.737	Validation loss : 8.108
# \ nEPOCH 83:\ tTraining loss : 11.623	Validation loss : 8.140
# \ nEPOCH 84:\ tTraining loss : 11.630	Validation loss : 8.201
# \ nEPOCH 85:\ tTraining loss : 11.493	Validation loss : 8.181
# \ nEPOCH 86:\ tTraining loss : 11.689	Validation loss : 8.690
# \ nEPOCH 87:\ tTraining loss : 11.853	Validation loss : 9.616
# \ nEPOCH 88:\ tTraining loss : 11.668	Validation loss : 9.092
# \ nEPOCH 89:\ tTraining loss : 11.896	Validation loss : 7.426
# \ nEPOCH 90:\ tTraining loss : 11.839	Validation loss : 7.429
# \ nEPOCH 91:\ tTraining loss : 11.716	Validation loss : 7.992
# \ nEPOCH 92:\ tTraining loss : 11.877	Validation loss : 9.034
# \ nEPOCH 93:\ tTraining loss : 11.714	Validation loss : 7.822
# \ nEPOCH 94:\ tTraining loss : 11.639	Validation loss : 7.512
# \ nEPOCH 95:\ tTraining loss : 12.129	Validation loss : 8.238
# \ nEPOCH 96:\ tTraining loss : 11.476	Validation loss : 9.346
# \ nEPOCH 97:\ tTraining loss : 12.271	Validation loss : 7.300
# \ nEPOCH 98:\ tTraining loss : 11.983	Validation loss : 8.580
# \ nEPOCH 99:\ tTraining loss : 11.722	Validation loss : 7.567
# \ nEPOCH 100:\ tTraining loss : 11.836	Validation loss : 7.608
# Evaluation on test set :
# R2: 0.8289693593978882

# %% [markdown]
# # **Sigmoid (Testing)**

# %%
# Construct MLP network
class MLP(nn.Module):
  def __init__(self, input_dims, hidden_dims, output_dims):
    super().__init__()
    self.linear1 = nn.Linear(input_dims, hidden_dims)
    self.linear2 = nn.Linear(hidden_dims, hidden_dims)
    self.output = nn.Linear(hidden_dims, output_dims)

  def forward(self, x):
    x = self.linear1(x) #Input to first hidden layer
    x = F.sigmoid(x) #First hidden layer to activation function
    x = self.linear2(x) #First activation to second hidden layer
    x = F.sigmoid(x) #to second activation function
    out = self.output(x) #to output
    return out.squeeze(1) #remove dimensions which equals to 1

input_dims = X.shape[1]
hidden_dims = 64
output_dims = 1

Sig_model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

# Loss and Optimizer
lr = 0.01
Sig_criterion = nn.MSELoss()
Sig_optimizer = torch.optim.SGD(Sig_model.parameters(), lr=lr)

# Training
epochs = 100
train_losses = []
train_r2 = []
val_losses = []
val_r2 = []
for epoch in range(epochs):
  # Training part
  train_loss = 0.0
  train_target = []
  train_predict = []
  Sig_model.train()

  for X_samples, y_samples in train_loader:
    X_samples = X_samples.to(device)
    y_samples = y_samples.to(device)
    Sig_optimizer.zero_grad()
    outputs = Sig_model(X_samples)
    train_predict += outputs.tolist() #Like append to list
    train_target += y_samples.tolist()
    loss = Sig_criterion(outputs, y_samples)
    loss.backward()
    Sig_optimizer.step()
    train_loss += loss.item()

  train_loss /= len(train_loader)
  train_losses.append(train_loss)
  train_r2.append(r_squared(train_predict, train_target))
  Sig_model.eval()

  # Evaluating part
  val_loss = 0.0
  val_target = []
  val_predict = []
  with torch.no_grad():
    for X_samples, y_samples in val_loader:
      X_samples = X_samples.to(device)
      y_samples = y_samples.to(device)
      outputs = Sig_model(X_samples)
      val_predict += outputs.tolist()
      val_target += y_samples.tolist()
      loss = Sig_criterion(outputs, y_samples)
      val_loss += loss.item()
  val_loss /= len(val_loader)
  val_losses.append(val_loss)
  val_r2.append(r_squared(val_predict, val_target))
  print (f'\ nEPOCH { epoch + 1}:\ tTraining loss : { train_loss :.3f}\tValidation loss : { val_loss :.3f}')

# Model Evaluation
Sig_model.eval()
with torch.no_grad():
  y_pred = Sig_model (X_test)
  test_set_r2 = r_squared(y_pred, y_test)
  print ('Evaluation on test set :')
  print (f'R2: { test_set_r2 }')
# Out:
# \ nEPOCH 1:\ tTraining loss : 159.112	Validation loss : 49.370
# \ nEPOCH 2:\ tTraining loss : 46.222	Validation loss : 36.762
# \ nEPOCH 3:\ tTraining loss : 32.557	Validation loss : 20.474
# \ nEPOCH 4:\ tTraining loss : 24.521	Validation loss : 12.981
# \ nEPOCH 5:\ tTraining loss : 19.542	Validation loss : 10.349
# \ nEPOCH 6:\ tTraining loss : 17.249	Validation loss : 9.986
# \ nEPOCH 7:\ tTraining loss : 15.782	Validation loss : 7.910
# \ nEPOCH 8:\ tTraining loss : 14.600	Validation loss : 7.519
# \ nEPOCH 9:\ tTraining loss : 14.079	Validation loss : 16.591
# \ nEPOCH 10:\ tTraining loss : 13.794	Validation loss : 7.938
# \ nEPOCH 11:\ tTraining loss : 12.805	Validation loss : 9.244
# \ nEPOCH 12:\ tTraining loss : 13.817	Validation loss : 10.393
# \ nEPOCH 13:\ tTraining loss : 13.082	Validation loss : 7.729
# \ nEPOCH 14:\ tTraining loss : 11.465	Validation loss : 8.578
# \ nEPOCH 15:\ tTraining loss : 11.710	Validation loss : 8.252
# \ nEPOCH 16:\ tTraining loss : 11.117	Validation loss : 7.226
# \ nEPOCH 17:\ tTraining loss : 10.840	Validation loss : 6.554
# \ nEPOCH 18:\ tTraining loss : 10.657	Validation loss : 6.783
# \ nEPOCH 19:\ tTraining loss : 11.546	Validation loss : 9.189
# \ nEPOCH 20:\ tTraining loss : 10.798	Validation loss : 7.043
# \ nEPOCH 21:\ tTraining loss : 10.955	Validation loss : 9.379
# \ nEPOCH 22:\ tTraining loss : 10.659	Validation loss : 6.600
# \ nEPOCH 65:\ tTraining loss : 8.397	Validation loss : 5.870
# \ nEPOCH 66:\ tTraining loss : 7.740	Validation loss : 6.314
# \ nEPOCH 67:\ tTraining loss : 7.792	Validation loss : 5.994
# \ nEPOCH 68:\ tTraining loss : 8.820	Validation loss : 6.956
# \ nEPOCH 69:\ tTraining loss : 8.611	Validation loss : 7.119
# \ nEPOCH 70:\ tTraining loss : 8.059	Validation loss : 5.428
# \ nEPOCH 71:\ tTraining loss : 8.043	Validation loss : 6.347
# \ nEPOCH 72:\ tTraining loss : 8.424	Validation loss : 5.716
# \ nEPOCH 73:\ tTraining loss : 8.310	Validation loss : 7.120
# \ nEPOCH 74:\ tTraining loss : 8.889	Validation loss : 6.327
# \ nEPOCH 75:\ tTraining loss : 8.133	Validation loss : 6.437
# \ nEPOCH 76:\ tTraining loss : 8.493	Validation loss : 5.942
# \ nEPOCH 77:\ tTraining loss : 8.461	Validation loss : 5.738
# \ nEPOCH 78:\ tTraining loss : 8.156	Validation loss : 5.226
# \ nEPOCH 79:\ tTraining loss : 8.652	Validation loss : 5.144
# \ nEPOCH 80:\ tTraining loss : 8.036	Validation loss : 7.961
# \ nEPOCH 81:\ tTraining loss : 8.545	Validation loss : 4.924
# \ nEPOCH 82:\ tTraining loss : 8.461	Validation loss : 5.745
# \ nEPOCH 83:\ tTraining loss : 8.374	Validation loss : 5.549
# \ nEPOCH 84:\ tTraining loss : 9.052	Validation loss : 5.912
# \ nEPOCH 85:\ tTraining loss : 8.049	Validation loss : 4.908
# \ nEPOCH 86:\ tTraining loss : 8.543	Validation loss : 7.412
# \ nEPOCH 87:\ tTraining loss : 8.514	Validation loss : 7.708
# \ nEPOCH 88:\ tTraining loss : 8.505	Validation loss : 5.114
# \ nEPOCH 89:\ tTraining loss : 8.028	Validation loss : 4.611
# \ nEPOCH 90:\ tTraining loss : 8.122	Validation loss : 5.537
# \ nEPOCH 91:\ tTraining loss : 7.520	Validation loss : 4.559
# \ nEPOCH 92:\ tTraining loss : 8.177	Validation loss : 5.868
# \ nEPOCH 93:\ tTraining loss : 7.554	Validation loss : 5.164
# \ nEPOCH 94:\ tTraining loss : 8.952	Validation loss : 6.132
# \ nEPOCH 95:\ tTraining loss : 8.334	Validation loss : 5.085
# \ nEPOCH 96:\ tTraining loss : 8.045	Validation loss : 5.895
# \ nEPOCH 97:\ tTraining loss : 8.444	Validation loss : 5.858
# \ nEPOCH 98:\ tTraining loss : 7.661	Validation loss : 4.823
# \ nEPOCH 99:\ tTraining loss : 7.957	Validation loss : 5.855
# \ nEPOCH 100:\ tTraining loss : 7.693	Validation loss : 5.999
# Evaluation on test set :
# R2: 0.8797475695610046

# %% [markdown]
# # **Tanh (Testing)**

# %%
# Construct MLP network
class MLP(nn.Module):
  def __init__(self, input_dims, hidden_dims, output_dims):
    super().__init__()
    self.linear1 = nn.Linear(input_dims, hidden_dims)
    self.linear2 = nn.Linear(hidden_dims, hidden_dims)
    self.output = nn.Linear(hidden_dims, output_dims)

  def forward(self, x):
    x = self.linear1(x) #Input to first hidden layer
    x = F.tanh(x) #First hidden layer to activation function
    x = self.linear2(x) #First activation to second hidden layer
    x = F.tanh(x) #to second activation function
    out = self.output(x) #to output
    return out.squeeze(1) #remove dimensions which equals to 1

input_dims = X.shape[1]
hidden_dims = 64
output_dims = 1

Tanh_model = MLP(input_dims=input_dims,
            hidden_dims=hidden_dims,
            output_dims=output_dims).to(device)

# Loss and Optimizer
lr = 0.01
Tanh_criterion = nn.MSELoss()
Tanh_optimizer = torch.optim.SGD(Tanh_model.parameters(), lr=lr)

# Training
epochs = 100
train_losses = []
train_r2 = []
val_losses = []
val_r2 = []
for epoch in range(epochs):
  # Training part
  train_loss = 0.0
  train_target = []
  train_predict = []
  Tanh_model.train()

  for X_samples, y_samples in train_loader:
    X_samples = X_samples.to(device)
    y_samples = y_samples.to(device)
    Tanh_optimizer.zero_grad()
    outputs = Tanh_model(X_samples)
    train_predict += outputs.tolist() #Like append to list
    train_target += y_samples.tolist()
    loss = Tanh_criterion(outputs, y_samples)
    loss.backward()
    Tanh_optimizer.step()
    train_loss += loss.item()

  train_loss /= len(train_loader)
  train_losses.append(train_loss)
  train_r2.append(r_squared(train_predict, train_target))
  Tanh_model.eval()

  # Evaluating part
  val_loss = 0.0
  val_target = []
  val_predict = []
  with torch.no_grad():
    for X_samples, y_samples in val_loader:
      X_samples = X_samples.to(device)
      y_samples = y_samples.to(device)
      outputs = Tanh_model(X_samples)
      val_predict += outputs.tolist()
      val_target += y_samples.tolist()
      loss = Tanh_criterion(outputs, y_samples)
      val_loss += loss.item()
  val_loss /= len(val_loader)
  val_losses.append(val_loss)
  val_r2.append(r_squared(val_predict, val_target))
  print (f'\ nEPOCH { epoch + 1}:\ tTraining loss : { train_loss :.3f}\tValidation loss : { val_loss :.3f}')

# Model Evaluation
Sig_model.eval()
with torch.no_grad():
  y_pred = Sig_model (X_test)
  test_set_r2 = r_squared(y_pred, y_test)
  print ('Evaluation on test set :')
  print (f'R2: { test_set_r2 }')
# Out:
# \ nEPOCH 1:\ tTraining loss : 251.247	Validation loss : 20.654
# \ nEPOCH 2:\ tTraining loss : 23.323	Validation loss : 13.905
# \ nEPOCH 3:\ tTraining loss : 16.478	Validation loss : 10.105
# \ nEPOCH 4:\ tTraining loss : 13.665	Validation loss : 8.323
# \ nEPOCH 5:\ tTraining loss : 12.257	Validation loss : 10.261
# \ nEPOCH 6:\ tTraining loss : 10.792	Validation loss : 6.966
# \ nEPOCH 7:\ tTraining loss : 10.360	Validation loss : 6.028
# \ nEPOCH 8:\ tTraining loss : 10.256	Validation loss : 7.487
# \ nEPOCH 9:\ tTraining loss : 11.207	Validation loss : 5.286
# \ nEPOCH 10:\ tTraining loss : 9.569	Validation loss : 9.980
# \ nEPOCH 11:\ tTraining loss : 9.795	Validation loss : 4.971
# \ nEPOCH 12:\ tTraining loss : 8.670	Validation loss : 7.322
# \ nEPOCH 13:\ tTraining loss : 8.129	Validation loss : 7.768
# \ nEPOCH 14:\ tTraining loss : 8.775	Validation loss : 5.393
# \ nEPOCH 15:\ tTraining loss : 8.314	Validation loss : 7.674
# \ nEPOCH 16:\ tTraining loss : 8.469	Validation loss : 4.908
# \ nEPOCH 17:\ tTraining loss : 8.242	Validation loss : 4.696
# \ nEPOCH 60:\ tTraining loss : 6.107	Validation loss : 6.109
# \ nEPOCH 61:\ tTraining loss : 5.894	Validation loss : 5.703
# \ nEPOCH 62:\ tTraining loss : 5.933	Validation loss : 4.802
# \ nEPOCH 63:\ tTraining loss : 5.727	Validation loss : 9.521
# \ nEPOCH 64:\ tTraining loss : 6.395	Validation loss : 6.055
# \ nEPOCH 65:\ tTraining loss : 5.741	Validation loss : 5.213
# \ nEPOCH 66:\ tTraining loss : 5.624	Validation loss : 6.374
# \ nEPOCH 67:\ tTraining loss : 5.659	Validation loss : 6.226
# \ nEPOCH 68:\ tTraining loss : 5.588	Validation loss : 7.492
# \ nEPOCH 69:\ tTraining loss : 6.151	Validation loss : 5.463
# \ nEPOCH 70:\ tTraining loss : 5.298	Validation loss : 5.397
# \ nEPOCH 71:\ tTraining loss : 5.436	Validation loss : 5.202
# \ nEPOCH 72:\ tTraining loss : 5.282	Validation loss : 5.156
# \ nEPOCH 73:\ tTraining loss : 5.638	Validation loss : 5.940
# \ nEPOCH 74:\ tTraining loss : 5.794	Validation loss : 5.653
# \ nEPOCH 75:\ tTraining loss : 5.599	Validation loss : 6.486
# \ nEPOCH 76:\ tTraining loss : 5.926	Validation loss : 5.354
# \ nEPOCH 77:\ tTraining loss : 5.323	Validation loss : 5.873
# \ nEPOCH 78:\ tTraining loss : 5.646	Validation loss : 6.093
# \ nEPOCH 79:\ tTraining loss : 5.500	Validation loss : 5.746
# \ nEPOCH 80:\ tTraining loss : 5.081	Validation loss : 6.341
# \ nEPOCH 81:\ tTraining loss : 5.368	Validation loss : 7.748
# \ nEPOCH 82:\ tTraining loss : 5.284	Validation loss : 6.016
# \ nEPOCH 83:\ tTraining loss : 5.324	Validation loss : 5.999
# \ nEPOCH 84:\ tTraining loss : 4.865	Validation loss : 5.947
# \ nEPOCH 85:\ tTraining loss : 5.256	Validation loss : 5.287
# \ nEPOCH 86:\ tTraining loss : 5.086	Validation loss : 5.540
# \ nEPOCH 87:\ tTraining loss : 5.501	Validation loss : 5.811
# \ nEPOCH 88:\ tTraining loss : 5.100	Validation loss : 5.279
# \ nEPOCH 89:\ tTraining loss : 4.789	Validation loss : 5.804
# \ nEPOCH 90:\ tTraining loss : 5.271	Validation loss : 5.006
# \ nEPOCH 91:\ tTraining loss : 5.302	Validation loss : 8.104
# \ nEPOCH 92:\ tTraining loss : 5.179	Validation loss : 8.417
# \ nEPOCH 93:\ tTraining loss : 4.855	Validation loss : 5.751
# \ nEPOCH 94:\ tTraining loss : 4.384	Validation loss : 5.859
# \ nEPOCH 95:\ tTraining loss : 4.858	Validation loss : 5.803
# \ nEPOCH 96:\ tTraining loss : 4.861	Validation loss : 6.113
# \ nEPOCH 97:\ tTraining loss : 5.032	Validation loss : 7.403
# \ nEPOCH 98:\ tTraining loss : 5.018	Validation loss : 7.049
# \ nEPOCH 99:\ tTraining loss : 5.378	Validation loss : 7.125
# \ nEPOCH 100:\ tTraining loss : 5.148	Validation loss : 5.346
# Evaluation on test set :
# R2: 0.8797475695610046
